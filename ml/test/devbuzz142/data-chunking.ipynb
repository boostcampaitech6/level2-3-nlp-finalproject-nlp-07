# %%
# !pip install transformers
# !pip install note_seq
# !pip install pygame
# !pip install torch==2.0.1
# !pip install miditoolkit # MidiFile() 로 midi file 읽어오기 위한 라이브러리
# Out:
# Requirement already satisfied: transformers in /opt/homebrew/anaconda3/envs/lakh-gpt2/lib/python3.9/site-packages (4.37.1)
# Requirement already satisfied: filelock in /opt/homebrew/anaconda3/envs/lakh-gpt2/lib/python3.9/site-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /opt/homebrew/anaconda3/envs/lakh-gpt2/lib/python3.9/site-packages (from transformers) (0.20.3)
# Requirement already satisfied: numpy>=1.17 in /opt/homebrew/anaconda3/envs/lakh-gpt2/lib/python3.9/site-packages (from transformers) (1.26.3)
# Requirement already satisfied: packaging>=20.0 in /opt/homebrew/anaconda3/envs/lakh-gpt2/lib/python3.9/site-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /opt/homebrew/anaconda3/envs/lakh-gpt2/lib/python3.9/site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /opt/homebrew/anaconda3/envs/lakh-gpt2/lib/python3.9/site-packages (from transformers) (2023.12.25)
# Requirement already satisfied: requests in /opt/homebrew/anaconda3/envs/lakh-gpt2/lib/python3.9/site-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /opt/homebrew/anaconda3/envs/lakh-gpt2/lib/python3.9/site-packages (from transformers) (0.15.1)
# Requirement already satisfied: safetensors>=0.3.1 in /opt/homebrew/anaconda3/envs/lakh-gpt2/lib/python3.9/site-packages (from transformers) (0.4.2)
# Requirement already satisfied: tqdm>=4.27 in /opt/homebrew/anaconda3/envs/lakh-gpt2/lib/python3.9/site-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/homebrew/anaconda3/envs/lakh-gpt2/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (2023.12.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/homebrew/anaconda3/envs/lakh-gpt2/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/homebrew/anaconda3/envs/lakh-gpt2/lib/python3.9/site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/anaconda3/envs/lakh-gpt2/lib/python3.9/site-packages (from requests->transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/homebrew/anaconda3/envs/lakh-gpt2/lib/python3.9/site-packages (from requests->transformers) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/anaconda3/envs/lakh-gpt2/lib/python3.9/site-packages (from requests->transformers) (2023.11.17)
# Requirement already satisfied: note_seq in /opt/homebrew/anaconda3/envs/lakh-gpt2/lib/python3.9/site-packages (0.0.5)
# Requirement already satisfied: absl-py in /opt/homebrew/anaconda3/envs/lakh-gpt2/lib/python3.9/site-packages (from note_seq) (2.1.0)
# Requirement already satisfied: attrs in /opt/homebrew/anaconda3/envs/lakh-gpt2/lib/python3.9/site-packages (from note_seq) (23.2.0)
# Requirement already satisfied: bokeh>=0.12.0 in /opt/homebrew/anaconda3/envs/lakh-gpt2/lib/python3.9/site-packages (from note_seq) (3.3.4)
# Requirement already satisfied: intervaltree>=2.1.0 in /opt/homebrew/anaconda3/envs/lakh-gpt2/lib/python3.9/site-packages (from note_seq) (3.1.0)
# Requirement already satisfied: IPython in /opt/homebrew/anaconda3/envs/lakh-gpt2/lib/python3.9/site-packages (from note_seq) (8.18.1)
# Requirement already satisfied: librosa>=0.6.2 in /opt/homebrew/anaconda3/envs/lakh-gpt2/lib/python3.9/site-packages (from note_seq) (0.10.1)
# Requirement already satisfied: numpy in /opt/homebrew/anaconda3/envs/lakh-gpt2/lib/python3.9/site-packages (from note_seq) (1.26.3)
# Requirement already satisfied: pandas>=0.18.1 in /opt/homebrew/anaconda3/envs/lakh-gpt2/lib/python3.9/site-packages (from note_seq) (2.2.0)
# Requirement already satisfied: pretty-midi>=0.2.6 in /opt/homebrew/anaconda3/envs/lakh-gpt2/lib/python3.9/site-packages (from note_seq) (0.2.10)
# Requirement already satisfied: protobuf>=4.21.2 in /opt/homebrew/anaconda3/envs/lakh-gpt2/lib/python3.9/site-packages (from note_seq) (4.25.2)
# Requirement already satisfied: pydub in /opt/homebrew/anaconda3/envs/lakh-gpt2/lib/python3.9/site-packages (from note_seq) (0.25.1)
# Requirement already satisfied: scipy>=0.18.1 in /opt/homebrew/anaconda3/envs/lakh-gpt2/lib/python3.9/site-packages (from note_seq) (1.12.0)
# Requirement already satisfied: Jinja2>=2.9 in /opt/homebrew/anaconda3/envs/lakh-gpt2/lib/python3.9/site-packages (from bokeh>=0.12.0->note_seq) (3.1.3)
# Requirement already satisfied: contourpy>=1 in /opt/homebrew/anaconda3/envs/lakh-gpt2/lib/python3.9/site-packages (from bokeh>=0.12.0->note_seq) (1.2.0)
# Requirement already satisfied: packaging>=16.8 in /opt/homebrew/anaconda3/envs/lakh-gpt2/lib/python3.9/site-packages (from bokeh>=0.12.0->note_seq) (23.2)
# Requirement already satisfied: pillow>=7.1.0 in /opt/homebrew/anaconda3/envs/lakh-gpt2/lib/python3.9/site-packages (from bokeh>=0.12.0->note_seq) (10.2.0)
# Requirement already satisfied: PyYAML>=3.10 in /opt/homebrew/anaconda3/envs/lakh-gpt2/lib/python3.9/site-packages (from bokeh>=0.12.0->note_seq) (6.0.1)
# Requirement already satisfied: tornado>=5.1 in /opt/homebrew/anaconda3/envs/lakh-gpt2/lib/python3.9/site-packages (from bokeh>=0.12.0->note_seq) (6.4)
# Requirement already satisfied: xyzservices>=2021.09.1 in /opt/homebrew/anaconda3/envs/lakh-gpt2/lib/python3.9/site-packages (from bokeh>=0.12.0->note_seq) (2023.10.1)
# Requirement already satisfied: sortedcontainers<3.0,>=2.0 in /opt/homebrew/anaconda3/envs/lakh-gpt2/lib/python3.9/site-packages (from intervaltree>=2.1.0->note_seq) (2.4.0)
# Requirement already satisfied: audioread>=2.1.9 in /opt/homebrew/anaconda3/envs/lakh-gpt2/lib/python3.9/site-packages (from librosa>=0.6.2->note_seq) (3.0.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in /opt/homebrew/anaconda3/envs/lakh-gpt2/lib/python3.9/site-packages (from librosa>=0.6.2->note_seq) (1.4.0)
# Requirement already satisfied: joblib>=0.14 in /opt/homebrew/anaconda3/envs/lakh-gpt2/lib/python3.9/site-packages (from librosa>=0.6.2->note_seq) (1.3.2)
# Requirement already satisfied: decorator>=4.3.0 in /opt/homebrew/anaconda3/envs/lakh-gpt2/lib/python3.9/site-packages (from librosa>=0.6.2->note_seq) (5.1.1)
# Requirement already satisfied: numba>=0.51.0 in /opt/homebrew/anaconda3/envs/lakh-gpt2/lib/python3.9/site-packages (from librosa>=0.6.2->note_seq) (0.58.1)
# Requirement already satisfied: soundfile>=0.12.1 in /opt/homebrew/anaconda3/envs/lakh-gpt2/lib/python3.9/site-packages (from librosa>=0.6.2->note_seq) (0.12.1)
# Requirement already satisfied: pooch>=1.0 in /opt/homebrew/anaconda3/envs/lakh-gpt2/lib/python3.9/site-packages (from librosa>=0.6.2->note_seq) (1.8.0)
# Requirement already satisfied: soxr>=0.3.2 in /opt/homebrew/anaconda3/envs/lakh-gpt2/lib/python3.9/site-packages (from librosa>=0.6.2->note_seq) (0.3.7)
# Requirement already satisfied: typing-extensions>=4.1.1 in /opt/homebrew/anaconda3/envs/lakh-gpt2/lib/python3.9/site-packages (from librosa>=0.6.2->note_seq) (4.9.0)
# Requirement already satisfied: lazy-loader>=0.1 in /opt/homebrew/anaconda3/envs/lakh-gpt2/lib/python3.9/site-packages (from librosa>=0.6.2->note_seq) (0.3)
# Requirement already satisfied: msgpack>=1.0 in /opt/homebrew/anaconda3/envs/lakh-gpt2/lib/python3.9/site-packages (from librosa>=0.6.2->note_seq) (1.0.7)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/homebrew/anaconda3/envs/lakh-gpt2/lib/python3.9/site-packages (from pandas>=0.18.1->note_seq) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/anaconda3/envs/lakh-gpt2/lib/python3.9/site-packages (from pandas>=0.18.1->note_seq) (2023.4)
# Requirement already satisfied: tzdata>=2022.7 in /opt/homebrew/anaconda3/envs/lakh-gpt2/lib/python3.9/site-packages (from pandas>=0.18.1->note_seq) (2023.4)
# Requirement already satisfied: mido>=1.1.16 in /opt/homebrew/anaconda3/envs/lakh-gpt2/lib/python3.9/site-packages (from pretty-midi>=0.2.6->note_seq) (1.3.2)
# Requirement already satisfied: six in /opt/homebrew/anaconda3/envs/lakh-gpt2/lib/python3.9/site-packages (from pretty-midi>=0.2.6->note_seq) (1.16.0)
# Requirement already satisfied: jedi>=0.16 in /opt/homebrew/anaconda3/envs/lakh-gpt2/lib/python3.9/site-packages (from IPython->note_seq) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /opt/homebrew/anaconda3/envs/lakh-gpt2/lib/python3.9/site-packages (from IPython->note_seq) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /opt/homebrew/anaconda3/envs/lakh-gpt2/lib/python3.9/site-packages (from IPython->note_seq) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in /opt/homebrew/anaconda3/envs/lakh-gpt2/lib/python3.9/site-packages (from IPython->note_seq) (2.17.2)
# Requirement already satisfied: stack-data in /opt/homebrew/anaconda3/envs/lakh-gpt2/lib/python3.9/site-packages (from IPython->note_seq) (0.6.3)
# Requirement already satisfied: traitlets>=5 in /opt/homebrew/anaconda3/envs/lakh-gpt2/lib/python3.9/site-packages (from IPython->note_seq) (5.14.1)
# Requirement already satisfied: exceptiongroup in /opt/homebrew/anaconda3/envs/lakh-gpt2/lib/python3.9/site-packages (from IPython->note_seq) (1.2.0)
# Requirement already satisfied: pexpect>4.3 in /opt/homebrew/anaconda3/envs/lakh-gpt2/lib/python3.9/site-packages (from IPython->note_seq) (4.9.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /opt/homebrew/anaconda3/envs/lakh-gpt2/lib/python3.9/site-packages (from jedi>=0.16->IPython->note_seq) (0.8.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/homebrew/anaconda3/envs/lakh-gpt2/lib/python3.9/site-packages (from Jinja2>=2.9->bokeh>=0.12.0->note_seq) (2.1.4)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /opt/homebrew/anaconda3/envs/lakh-gpt2/lib/python3.9/site-packages (from numba>=0.51.0->librosa>=0.6.2->note_seq) (0.41.1)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/homebrew/anaconda3/envs/lakh-gpt2/lib/python3.9/site-packages (from pexpect>4.3->IPython->note_seq) (0.7.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /opt/homebrew/anaconda3/envs/lakh-gpt2/lib/python3.9/site-packages (from pooch>=1.0->librosa>=0.6.2->note_seq) (4.1.0)
# Requirement already satisfied: requests>=2.19.0 in /opt/homebrew/anaconda3/envs/lakh-gpt2/lib/python3.9/site-packages (from pooch>=1.0->librosa>=0.6.2->note_seq) (2.31.0)
# Requirement already satisfied: wcwidth in /opt/homebrew/anaconda3/envs/lakh-gpt2/lib/python3.9/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->IPython->note_seq) (0.2.13)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/homebrew/anaconda3/envs/lakh-gpt2/lib/python3.9/site-packages (from scikit-learn>=0.20.0->librosa>=0.6.2->note_seq) (3.2.0)
# Requirement already satisfied: cffi>=1.0 in /opt/homebrew/anaconda3/envs/lakh-gpt2/lib/python3.9/site-packages (from soundfile>=0.12.1->librosa>=0.6.2->note_seq) (1.16.0)
# Requirement already satisfied: executing>=1.2.0 in /opt/homebrew/anaconda3/envs/lakh-gpt2/lib/python3.9/site-packages (from stack-data->IPython->note_seq) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/homebrew/anaconda3/envs/lakh-gpt2/lib/python3.9/site-packages (from stack-data->IPython->note_seq) (2.4.1)
# Requirement already satisfied: pure-eval in /opt/homebrew/anaconda3/envs/lakh-gpt2/lib/python3.9/site-packages (from stack-data->IPython->note_seq) (0.2.2)
# Requirement already satisfied: pycparser in /opt/homebrew/anaconda3/envs/lakh-gpt2/lib/python3.9/site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa>=0.6.2->note_seq) (2.21)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/homebrew/anaconda3/envs/lakh-gpt2/lib/python3.9/site-packages (from requests>=2.19.0->pooch>=1.0->librosa>=0.6.2->note_seq) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/anaconda3/envs/lakh-gpt2/lib/python3.9/site-packages (from requests>=2.19.0->pooch>=1.0->librosa>=0.6.2->note_seq) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/homebrew/anaconda3/envs/lakh-gpt2/lib/python3.9/site-packages (from requests>=2.19.0->pooch>=1.0->librosa>=0.6.2->note_seq) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/anaconda3/envs/lakh-gpt2/lib/python3.9/site-packages (from requests>=2.19.0->pooch>=1.0->librosa>=0.6.2->note_seq) (2023.11.17)
# Requirement already satisfied: pygame in /opt/homebrew/anaconda3/envs/lakh-gpt2/lib/python3.9/site-packages (2.5.2)
# Requirement already satisfied: torch==2.0.1 in /opt/homebrew/anaconda3/envs/lakh-gpt2/lib/python3.9/site-packages (2.0.1)
# Requirement already satisfied: filelock in /opt/homebrew/anaconda3/envs/lakh-gpt2/lib/python3.9/site-packages (from torch==2.0.1) (3.13.1)
# Requirement already satisfied: typing-extensions in /opt/homebrew/anaconda3/envs/lakh-gpt2/lib/python3.9/site-packages (from torch==2.0.1) (4.9.0)
# Requirement already satisfied: sympy in /opt/homebrew/anaconda3/envs/lakh-gpt2/lib/python3.9/site-packages (from torch==2.0.1) (1.12)
# Requirement already satisfied: networkx in /opt/homebrew/anaconda3/envs/lakh-gpt2/lib/python3.9/site-packages (from torch==2.0.1) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/homebrew/anaconda3/envs/lakh-gpt2/lib/python3.9/site-packages (from torch==2.0.1) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/homebrew/anaconda3/envs/lakh-gpt2/lib/python3.9/site-packages (from jinja2->torch==2.0.1) (2.1.4)
# Requirement already satisfied: mpmath>=0.19 in /opt/homebrew/anaconda3/envs/lakh-gpt2/lib/python3.9/site-packages (from sympy->torch==2.0.1) (1.3.0)
# Collecting miditoolkit
#   Downloading miditoolkit-1.0.1-py3-none-any.whl.metadata (4.9 kB)
# Collecting matplotlib (from miditoolkit)
#   Downloading matplotlib-3.8.2-cp39-cp39-macosx_11_0_arm64.whl.metadata (5.8 kB)
# Requirement already satisfied: mido>=1.1.16 in /opt/homebrew/anaconda3/envs/lakh-gpt2/lib/python3.9/site-packages (from miditoolkit) (1.3.2)
# Requirement already satisfied: numpy>=1.19 in /opt/homebrew/anaconda3/envs/lakh-gpt2/lib/python3.9/site-packages (from miditoolkit) (1.26.3)
# Requirement already satisfied: packaging~=23.1 in /opt/homebrew/anaconda3/envs/lakh-gpt2/lib/python3.9/site-packages (from mido>=1.1.16->miditoolkit) (23.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/homebrew/anaconda3/envs/lakh-gpt2/lib/python3.9/site-packages (from matplotlib->miditoolkit) (1.2.0)
# Collecting cycler>=0.10 (from matplotlib->miditoolkit)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib->miditoolkit)
#   Downloading fonttools-4.47.2-cp39-cp39-macosx_10_9_universal2.whl.metadata (157 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 157.6/157.6 kB 7.5 MB/s eta 0:00:00
# Collecting kiwisolver>=1.3.1 (from matplotlib->miditoolkit)
#   Downloading kiwisolver-1.4.5-cp39-cp39-macosx_11_0_arm64.whl.metadata (6.4 kB)
# Requirement already satisfied: pillow>=8 in /opt/homebrew/anaconda3/envs/lakh-gpt2/lib/python3.9/site-packages (from matplotlib->miditoolkit) (10.2.0)
# Collecting pyparsing>=2.3.1 (from matplotlib->miditoolkit)
#   Using cached pyparsing-3.1.1-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/homebrew/anaconda3/envs/lakh-gpt2/lib/python3.9/site-packages (from matplotlib->miditoolkit) (2.8.2)
# Collecting importlib-resources>=3.2.0 (from matplotlib->miditoolkit)
#   Downloading importlib_resources-6.1.1-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: zipp>=3.1.0 in /opt/homebrew/anaconda3/envs/lakh-gpt2/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib->miditoolkit) (3.17.0)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/anaconda3/envs/lakh-gpt2/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib->miditoolkit) (1.16.0)
# Downloading miditoolkit-1.0.1-py3-none-any.whl (24 kB)
# Downloading matplotlib-3.8.2-cp39-cp39-macosx_11_0_arm64.whl (7.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 32.5 MB/s eta 0:00:0000:0100:01
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.47.2-cp39-cp39-macosx_10_9_universal2.whl (2.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 5.6 MB/s eta 0:00:00a 0:00:01m
# Downloading importlib_resources-6.1.1-py3-none-any.whl (33 kB)
# Downloading kiwisolver-1.4.5-cp39-cp39-macosx_11_0_arm64.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.2/66.2 kB 8.3 MB/s eta 0:00:00
# Using cached pyparsing-3.1.1-py3-none-any.whl (103 kB)
# Installing collected packages: pyparsing, kiwisolver, importlib-resources, fonttools, cycler, matplotlib, miditoolkit
# Successfully installed cycler-0.12.1 fonttools-4.47.2 importlib-resources-6.1.1 kiwisolver-1.4.5 matplotlib-3.8.2 miditoolkit-1.0.1 pyparsing-3.1.1

# %%
import os
import pygame

from copy import deepcopy
from math import ceil
from pathlib import Path
from miditoolkit import MidiFile
import pandas as pd

# %%
MAX_NB_BAR = 4
MIN_NB_NOTES = 20

# %%
midi_paths = list(Path('./ym-midis/midis').glob('*.mid'))

# %%
orig_names = [path.stem for path in midi_paths]

midi_data = pd.DataFrame(columns=['orig_name'], data=orig_names)
midi_data
# Out:
#                                           orig_name
# 0                  Out Run 3D (FM) - 05 - Last Wave
# 1                                       18 Darkmare
# 2            Solomon no Kagi (FM) - 01 - Main Theme
# 3                                          09 Glory
# 4                   Out Run (FM) - 03 - Splash Wave
# ..                                              ...
# 664             Double Dragon (FM) - 07 - Last Boss
# 665                                     18 Ending 3
# 666                                    11 Your Rank
# 667  12 Game Over (Namco Logo, The Tower of Druaga)
# 668                                     42 GET_Item
#
# [669 rows x 1 columns]

# %%
# replacte - with _
replaced_paths = [str(midi_path).replace('-', '_') for midi_path in orig_paths]
# replace white space with underscore
replaced_paths = [str(midi_path).replace(' ', '_') for midi_path in replaced_paths]
# replace continuos _ with single _
replaced_paths = [str(midi_path).replace('__', '_') for midi_path in replaced_paths]
replaced_paths = [str(midi_path).replace('__', '_') for midi_path in replaced_paths]
replaced_paths = [str(midi_path).replace('__', '_') for midi_path in replaced_paths]

midi_data['replaced_name'] = replaced_paths
midi_data
# Out:
#                                           orig_name  \
# 0                  Out Run 3D (FM) - 05 - Last Wave
# 1                                       18 Darkmare
# 2            Solomon no Kagi (FM) - 01 - Main Theme
# 3                                          09 Glory
# 4                   Out Run (FM) - 03 - Splash Wave
# ..                                              ...
# 664             Double Dragon (FM) - 07 - Last Boss
# 665                                     18 Ending 3
# 666                                    11 Your Rank
# 667  12 Game Over (Namco Logo, The Tower of Druaga)
# 668                                     42 GET_Item
#
#                                       replaced_name
# 0                      Out_Run_3D_(FM)_05_Last_Wave
# 1                                       18_Darkmare
# 2                Solomon_no_Kagi_(FM)_01_Main_Theme
# 3                                          09_Glory
# 4                       Out_Run_(FM)_03_Splash_Wave
# ..                                              ...
# 664                 Double_Dragon_(FM)_07_Last_Boss
# 665                                     18_Ending_3
# 666                                    11_Your_Rank
# 667  12_Game_Over_(Namco_Logo,_The_Tower_of_Druaga)
# 668                                     42_GET_Item
#
# [669 rows x 2 columns]

# %%
# sort by replaced_name
midi_data = midi_data.sort_values(by='replaced_name')

# reset index
midi_data = midi_data.reset_index(drop=True)
midi_data
# Out:
#                                              orig_name  \
# 0                                   01 A Ball of Light
# 1                                           01 Compile
# 2    01 - Game de check! Koutsuu Anzen (FM) - Instr...
# 3                     01 Hyper Defending Force (Title)
# 4                               01 Is it Domingo Today
# ..                                                 ...
# 664                Zillion II (FM) - 01 - Title Screen
# 665                  Zillion II (FM) - 02 - Pure Stone
# 666                 Zillion II (FM) - 03 - Inside Base
# 667                        Zillion II (FM) - 04 - Boss
# 668                       Zillion II (FM) - 05 - Push!
#
#                                          replaced_name
# 0                                   01_A_Ball_of_Light
# 1                                           01_Compile
# 2    01_Game_de_check!_Koutsuu_Anzen_(FM)_Instructions
# 3                     01_Hyper_Defending_Force_(Title)
# 4                               01_Is_it_Domingo_Today
# ..                                                 ...
# 664                    Zillion_II_(FM)_01_Title_Screen
# 665                      Zillion_II_(FM)_02_Pure_Stone
# 666                     Zillion_II_(FM)_03_Inside_Base
# 667                            Zillion_II_(FM)_04_Boss
# 668                           Zillion_II_(FM)_05_Push!
#
# [669 rows x 2 columns]

# %%
from mido import MidiFile

for i, midi_path in enumerate(midi_paths):  
    # avoid any Error
    try:
        midi = MidiFile(midi_path)
    except Exception as e:
        print("Skipping", midi_path, "because it's too short")
        continue
    
    ticks_per_cut = MAX_NB_BAR * midi.ticks_per_beat * 4
    nb_cut = ceil(midi.max_tick / ticks_per_cut)
    if nb_cut < 2:
        # if there is no midi_path.setm folder, create it
        if not os.path.exists(f'./ym-test/chunks/{midi_path.stem}'):
            os.makedirs(f'./ym-test/chunks/{midi_path.stem}')
        midi.dump(f'./ym-test/chunks/{midi_path.stem}/0.mid')
        print("Skipping", midi_path, "because it's too short")
        continue

    midi_cuts = [deepcopy(midi) for _ in range(nb_cut)]

    for j, track in enumerate(midi.instruments):
        track.notes = sorted(track.notes, key=lambda x: x.start)
        for midi_short in midi_cuts:
            midi_short.instruments[j].notes = []
        for note in track.notes:
            cut_idx = note.start // ticks_per_cut
            note_copy = deepcopy(note)
            note_copy.start -= cut_idx * ticks_per_cut
            note_copy.end -= cut_idx * ticks_per_cut
            midi_cuts[cut_idx].instruments[j].notes.append(note_copy)

    # saving midis
    for j, midi_short in enumerate(midi_cuts):
        if sum(len(track.notes) for track in midi_short.instruments) < MIN_NB_NOTES:
            print("Skipping", midi_path, "because it's too short")
            continue
        if not os.path.exists(f'./ym-test/chunks/{midi_path.stem}'):
            os.makedirs(f'./ym-test/chunks/{midi_path.stem}')
        midi_short.dump(f'./ym-test/chunks/{midi_path.stem}/{j}.mid')
# Out:
# Skipping ym-test/01 A Ball of Light.mid because it's too short
# Skipping ym-test/01 A Ball of Light.mid because it's too short
# Skipping ym-test/01 Hyper Defending Force (Title).mid because it's too short
# Skipping ym-test/01 Hyper Defending Force (Title).mid because it's too short
# Skipping ym-test/01 Hyper Defending Force (Title).mid because it's too short
# Skipping ym-test/01 Hyper Defending Force (Title).mid because it's too short
# Skipping ym-test/01 Hyper Defending Force (Title).mid because it's too short
# Skipping ym-test/01 Hyper Defending Force (Title).mid because it's too short
# Skipping ym-test/01 Hyper Defending Force (Title).mid because it's too short
# Skipping ym-test/01 Hyper Defending Force (Title).mid because it's too short
# Skipping ym-test/01 Hyper Defending Force (Title).mid because it's too short
# Skipping ym-test/01 Hyper Defending Force (Title).mid because it's too short
# Skipping ym-test/01 Hyper Defending Force (Title).mid because it's too short
# Skipping ym-test/01 Hyper Defending Force (Title).mid because it's too short
# Skipping ym-test/01 Is it Domingo Today.mid because it's too short
# Skipping ym-test/01 Is it Domingo Today.mid because it's too short
# Skipping ym-test/01 Is it Domingo Today.mid because it's too short
# Skipping ym-test/01 Is it Domingo Today.mid because it's too short
# Skipping ym-test/01 Is it Domingo Today.mid because it's too short
# Skipping ym-test/01 Is it Domingo Today.mid because it's too short
# Skipping ym-test/01 Compile.mid because it's too short
# Skipping ym-test/01 - Game de check! Koutsuu Anzen (FM) - Instructions.mid because it's too short
# Skipping ym-test/01 - Game de check! Koutsuu Anzen (FM) - Instructions.mid because it's too short
# Skipping ym-test/01 - Game de check! Koutsuu Anzen (FM) - Instructions.mid because it's too short
# Skipping ym-test/01 - Game de check! Koutsuu Anzen (FM) - Instructions.mid because it's too short
# Skipping ym-test/01 - Game de check! Koutsuu Anzen (FM) - Instructions.mid because it's too short

# %%
orig = MidiFile('./ym-test/01 - Game de check! Koutsuu Anzen (FM) - Instructions.mid')
orig.instruments
# Out:
# [Instrument(program=27, is_drum=False, name=) - 68 notes,
#  Instrument(program=32, is_drum=False, name=) - 114 notes,
#  Instrument(program=11, is_drum=False, name=) - 128 notes,
#  Instrument(program=81, is_drum=False, name=) - 68 notes,
#  Instrument(program=11, is_drum=False, name=) - 128 notes]

# %%
orig.dump('./ym-test/test.mid')

# %%
test = MidiFile('./ym-test/test.mid')
test.instruments
# Out:
# [Instrument(program=27, is_drum=False, name=) - 68 notes,
#  Instrument(program=32, is_drum=False, name=) - 114 notes,
#  Instrument(program=11, is_drum=False, name=) - 128 notes,
#  Instrument(program=81, is_drum=False, name=) - 68 notes,
#  Instrument(program=11, is_drum=False, name=) - 128 notes]

# %%
midi_paths
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 midi_paths
#
# NameError: name 'midi_paths' is not defined

# %%
midi_paths = list(Path('./ym-test').glob('*.mid'))
midi_paths.append(Path('./ym-test/gilbert hello #3 - Rickard.mid'))
midi_paths.append(Path('./ym-test/double  space.mid'))

midi_paths = list(Path('./YM2413-MDB-v1.0.0/midi/adjust_tempo').glob('*.mid'))
midi_paths
# Out:
# [PosixPath('YM2413-MDB-v1.0.0/midi/adjust_tempo/Out Run 3D (FM) - 05 - Last Wave.mid'),
#  PosixPath('YM2413-MDB-v1.0.0/midi/adjust_tempo/18 Darkmare.mid'),
#  PosixPath('YM2413-MDB-v1.0.0/midi/adjust_tempo/Solomon no Kagi (FM) - 01 - Main Theme.mid'),
#  PosixPath('YM2413-MDB-v1.0.0/midi/adjust_tempo/09 Glory.mid'),
#  PosixPath('YM2413-MDB-v1.0.0/midi/adjust_tempo/Out Run (FM) - 03 - Splash Wave.mid'),
#  PosixPath('YM2413-MDB-v1.0.0/midi/adjust_tempo/Megumi Rescue (FM) - 08 - Rounds 21-30.mid'),
#  PosixPath('YM2413-MDB-v1.0.0/midi/adjust_tempo/Phantasy Star (FM) - 05 - Palma.mid'),
#  PosixPath('YM2413-MDB-v1.0.0/midi/adjust_tempo/Shanghai (FM) - 06 - Well Done.mid'),
#  PosixPath('YM2413-MDB-v1.0.0/midi/adjust_tempo/Golvellius - Valley of Doom (FM) - 16 - Overworld 3.mid'),
#  PosixPath('YM2413-MDB-v1.0.0/midi/adjust_tempo/Wonder Boy III (FM) - 01 - The Last Dungeon.mid'),
#  PosixPath('YM2413-MDB-v1.0.0/midi/adjust_tempo/11 Calm Feeling.mid'),
#  PosixPath('YM2413-MDB-v1.0.0/midi/adjust_tempo/Out Run 3D (FM) - 02 - Midnight Highway.mid'),
#  PosixPath('YM2413-MDB-v1.0.0/midi/adjust_tempo/09 Mission 3.mid'),
#  PosixPath('YM2413-MDB-v1.0.0/midi/adjust_tempo/03 Pit Approach.mid'),
#  PosixPath('YM2413-MDB-v1.0.0/midi/adjust_tempo/Global Defense (FM) - 01 - Demo.mid'),
#  PosixPath('YM2413-MDB-v1.0.0/midi/adjust_tempo/Double Dragon (FM) - 04 - Mission 3.mid'),
#  PosixPath('YM2413-MDB-v1.0.0/midi/adjust_tempo/Megumi Rescue (FM) - 04 - Perfect.mid'),
#  PosixPath('YM2413-MDB-v1.0.0/midi/adjust_tempo/01 Title.mid'),
#  PosixPath('YM2413-MDB-v1.0.0/midi/adjust_tempo/21 Mission 9.mid'),
#  PosixPath('YM2413-MDB-v1.0.0/midi/adjust_tempo/08 - Game de check! Koutsuu Anzen (FM) - Game Over.mid'),
#  PosixPath('YM2413-MDB-v1.0.0/midi/adjust_tempo/20 Game Over.mid'),
#  PosixPath('YM2413-MDB-v1.0.0/midi/adjust_tempo/22 Ranking.mid'),
#  PosixPath('YM2413-MDB-v1.0.0/midi/adjust_tempo/07 Ruins.mid'),
#  PosixPath('YM2413-MDB-v1.0.0/midi/adjust_tempo/Power Strike, Aleste (FM) - 10 - Dogodaga-Dogodege.mid'),
#  PosixPath('YM2413-MDB-v1.0.0/midi/adjust_tempo/09 
mid'),
#  PosixPath('YM2413-MDB-v1.0.0/midi/adjust_tempo/Double Dragon (FM) - 07 - Last Boss.mid'),
#  PosixPath('YM2413-MDB-v1.0.0/midi/adjust_tempo/18 Ending 3.mid'),
#  PosixPath('YM2413-MDB-v1.0.0/midi/adjust_tempo/11 Your Rank.mid'),
#  PosixPath('YM2413-MDB-v1.0.0/midi/adjust_tempo/12 Game Over (Namco Logo, The Tower of Druaga).mid'),
#  PosixPath('YM2413-MDB-v1.0.0/midi/adjust_tempo/42 GET_Item.mid')]

# %%
# replacte - with _
midi_paths = [str(midi_path.stem).replace('-', '_') for midi_path in midi_paths]
# replace white space with underscore
midi_paths = [str(midi_path).replace(' ', '_') for midi_path in midi_paths]
# replace continuos _ with single _
midi_paths = [str(midi_path).replace('__', '_') for midi_path in midi_paths]
midi_paths = [str(midi_path).replace('__', '_') for midi_path in midi_paths]
midi_paths = [str(midi_path).replace('__', '_') for midi_path in midi_paths]
midi_paths
# Out:
# ['Out_Run_3D_(FM)_05_Last_Wave',
#  '18_Darkmare',
#  'Solomon_no_Kagi_(FM)_01_Main_Theme',
#  '09_Glory',
#  'Out_Run_(FM)_03_Splash_Wave',
#  'Megumi_Rescue_(FM)_08_Rounds_21_30',
#  'Phantasy_Star_(FM)_05_Palma',
#  'Shanghai_(FM)_06_Well_Done',
#  'Golvellius_Valley_of_Doom_(FM)_16_Overworld_3',
#  'Wonder_Boy_III_(FM)_01_The_Last_Dungeon',
#  '11_Calm_Feeling',
#  'Out_Run_3D_(FM)_02_Midnight_Highway',
#  '09_Mission_3',
#  '03_Pit_Approach',
#  'Global_Defense_(FM)_01_Demo',
#  'Double_Dragon_(FM)_04_Mission_3',
#  'Megumi_Rescue_(FM)_04_Perfect',
#  '01_Title',
#  '21_Mission_9',
#  '08_Game_de_check!_Koutsuu_Anzen_(FM)_Game_Over',
#  '20_Game_Over',
#  '22_Ranking',
#  '07_Ruins',
#  'Power_Strike,_Aleste_(FM)_10_Dogodaga_Dogodege',
#  '09_Zeodalley',
#  '06_Area_2_(Lost_World_The_Island)',
#  '14_Clear_#2',
#  '08_Big_Don',
#  '04_Turn_on_The_Run',
#  '11_Complete',
#  'Captain_Silver_(FM)_06_Scene_Complete',
#  '10_The_Devastation_(Area_4)',
#  'Galactic_Protector_(FM)_07_Ending',
#  'Galactic_Protector_(FM)_06_Perfect!',
#  '11_The_Solitude_(Area_5)',
#  '03_Palm',
#  'Wonder_Boy_III_(FM)_12_The_Monster_s_Lair',
#  'Power_Strike,_Aleste_(FM)_11_Go_Ahead',
#  '15_Name_Entry',
#  'Rambo_III_(FM)_01_Title_Screen',
#  '16_Demo_2',
#  'Cyborg_Hunter_(FM)_07_Ending_Credits',
#  'Power_Strike,_Aleste_(FM)_02_The_Challenger',
#  '07_Game_de_check!_Koutsuu_Anzen_(FM)_You_re_The_Best_Driver',
#  'Fantasy_Zone_II_(FM)_11_Shop',
#  'Wonder_Boy_III_(FM)_09_The_Danger_Zone',
#  'Wonder_Boy_in_Monster_Land_(FM)_10_Death',
#  '15_Staff_Roll_(Ending_Credits)',
#  '13_Demo',
#  '11_Sophistication_#3',
#  '01_A_Ball_of_Light',
#  '04_Metropolis_(Area_1)',
#  'Dynamite_Dux_(FM)_07_Achacha_the_Great',
#  '04_Battle',
#  '01_Title_Screen',
#  'Fantasy_Zone_II_(FM)_06_Chaprun',
#  '13_Don_t_Cry_Hi_Yah_(Area_7)',
#  'Miracle_Warriors_Seal_of_the_Dark_Lord_(FM)_07_Battle',
#  '24_Go_the_Waterway',
#  '06_Beyond_the_Dimension',
#  '05_Stage_1',
#  '22_Staff_Roll',
#  'Shanghai_(FM)_05_Dragon',
#  'Ys_(FM)_15_Rest_In_Peace',
#  'Out_Run_(FM)_04_Last_Wave',
#  'Miracle_Warriors_Seal_of_the_Dark_Lord_(FM)_04_Castle',
#  'Alex_Kidd_The_Lost_Stars_(FM)_06_Water_World',
#  '02_Start_Demo',
#  '54_The_Cave_of_Life_(The_Fountain_of_Youth)',
#  '03_Tuning_Mode',
#  'Fantasy_Zone_II_(FM)_03_Sarcand',
#  '05_Forest',
#  'Power_Strike,_Aleste_(FM)_09_Bloody_Jewel',
#  'Kenseiden_(FM)_12_Warlock_Battle',
#  'Solomon_no_Kagi_(FM)_09_Death',
#  'Kenseiden_(FM)_15_Game_Over',
#  '06_Fearless_Church',
#  'Galaxy_Force_(FM)_03_Try_Z',
#  '21_Ranking_Display',
#  '02_Ice_of_Death',
#  '08_The_Challenger_(Area_2)',
#  'Miracle_Warriors_Seal_of_the_Dark_Lord_(FM)_01_Title',
#  'Phantasy_Star_(FM)_01_Title_Screen',
#  'Kenseiden_(FM)_09_Victory',
#  'Altered_Beast_(FM)_06_Game_Over',
#  'Space_Harrier_3_D_(FM)_14_Syura',
#  '25_Save',
#  '06_Crisis_Area',
#  '09_Stage_3',
#  'Global_Defense_(FM)_04_Perfect',
#  '01_Peddler',
#  'Double_Dragon_(FM)_06_Boss',
#  'Golvellius_Valley_of_Doom_(FM)_09_First_Boss_Despa',
#  'Captain_Silver_(FM)_12_Death',
#  'Space_Harrier_3_D_(FM)_11_Squilla',
#  'Maze_Hunter_3_D_(FM)_07_Ending',
#  'Megumi_Rescue_(FM)_02_Rounds_1_10',
#  'Rambo_III_(FM)_09_Game_Over',
#  'Altered_Beast_(FM)_02_Transformed',
#  'Golvellius_Valley_of_Doom_(FM)_13_Horizontal_Scrolling_Cave',
#  '06_Celebration_2',
#  'Solomon_no_Kagi_(FM)_08_Ending',
#  'Power_Strike,_Aleste_(FM)_14_Again',
#  'Thunder_Blade_(FM)_03_Thunder_Blade',
#  '06_Field',
#  'Space_Harrier_3_D_(FM)_07_Volcano',
#  'Out_Run_3D_(FM)_01_Magical_Sound_Shower',
#  'Space_Harrier_3_D_(FM)_13_Goderni',
#  '10_Game_Set_(Won)',
#  '11_Sadness',
#  '05_Stage_3',
#  'Rampage_(FM)_05_Ending',
#  'Space_Harrier_3_D_(FM)_09_Danger_Area',
#  '26_Shock',
#  '03_Car_Select',
#  'Ys_(FM)_01_Feena',
#  '04_Interlude',
#  '13_Area_6_(What_s_Goin_on_in_the_Chase)',
#  'Golvellius_Valley_of_Doom_(FM)_06_Fairy',
#  'Zaxxon_3_D_(FM)_02_Outer_Space',
#  'Thunder_Blade_(FM)_04_Type_II',
#  'Golvellius_Valley_of_Doom_(FM)_12_Winkle',
#  'Solomon_no_Kagi_(FM)_02_Room_Clear',
#  'Rastan_(FM)_06_Scene_Clear',
#  'Golvellius_Valley_of_Doom_(FM)_22_Overworld_5',
#  'Altered_Beast_(FM)_04_Weredragon_Weretiger',
#  'Ys_(FM)_17_See_You_Again',
#  'Altered_Beast_(FM)_01_Werewolf_Gold_Werewolf',
#  'Megumi_Rescue_(FM)_01_Title_Screen',
#  'Fantasy_Zone_II_(FM)_02_Pastaria',
#  '08_Act_2,_7',
#  'Golvellius_Valley_of_Doom_(FM)_26_Final_Boss_Golvellius',
#  '16_Agnesia',
#  'Fantasy_Zone_II_(FM)_04_Hiyarika',
#  '03_Practice_Makes_Perfect',
#  '44_End_Logo',
#  'Penguin_Land_(FM)_03_Game_Start',
#  '23_In_Captivity',
#  'Captain_Silver_(FM)_03_Town_of_Barren_Pirate_Ship',
#  '04_Level_Clear',
#  '06_Unknown',
#  'Phantasy_Star_(FM)_14_Dezoris',
#  '10_Stage_4',
#  '16_Boss_6',
#  '05_Death',
#  'Out_Run_(FM)_01_Magical_Sound_Shower',
#  'Maze_Hunter_3_D_(FM)_04_Jungle_Area',
#  '07_Bonus',
#  'Double_Dragon_(FM)_03_Mission_2',
#  'Galaxy_Force_(FM)_06_Alone_Fighter',
#  'Wonder_Boy_in_Monster_Land_(FM)_09_Round_Clear',
#  'Space_Harrier_3_D_(FM)_16_White_Summer',
#  '08_Inorganic_Beat',
#  'Double_Dragon_(FM)_01_Title',
#  'Solomon_no_Kagi_(FM)_07_Solomon_s_Room',
#  'Wonder_Boy_in_Monster_Land_(FM)_02_Boss',
#  '22_Boss_9',
#  'Columns_(FM)_05_Atropos',
#  'Kenseiden_(FM)_14_Ending',
#  'Zaxxon_3_D_(FM)_05_Final_Boss',
#  'Wonder_Boy_III_(FM)_11_It_s_a_Treasure_Box',
#  '12_Game_de_check!_Koutsuu_Anzen_(FM)_Alex_Kidd_Jingle_(unused)',
#  '19_Valua_s_Feast',
#  'Out_Run_3D_(FM)_04_Shining_Wind',
#  'Phantasy_Star_(FM)_10_Story,_Conversations',
#  'Columns_(FM)_03_Clotho',
#  '11_Milly_s_Theme',
#  '10_Underground_Dungeon_(The_Lost_Talisman)',
#  'Rampage_(FM)_03_Level_Theme',
#  '07_Clear_#1',
#  '07_Dungeon',
#  '05_Mad_Flame',
#  'After_Burner_(FM)_05_Red_Out',
#  '07_Solvalou',
#  '13_Ending_#1',
#  '05_Demon_War',
#  'Wonder_Boy_III_(FM)_07_Mind_of_Hero',
#  'Space_Harrier_3_D_(FM)_06_Bright_Rays',
#  'BMX_Trial_Alex_Kidd_07_Game_Over',
#  '01_Opening_Theme',
#  '10_Return_of_Peace',
#  'California_Games_(FM)_08_BMX',
#  '12_Ultimate_Weapon_(Last_Boss)',
#  'Galactic_Protector_(FM)_05_Mars_Round',
#  'Double_Dragon_(FM)_02_Mission_1',
#  'BMX_Trial_Alex_Kidd_05_Ending',
#  'Golvellius_Valley_of_Doom_(FM)_21_Overworld_4',
#  'After_Burner_(FM)_03_After_Burner',
#  '18_Easy_Going_(Bonus_Area)',
#  '14_Boss_2',
#  'Kenseiden_(FM)_03_Map',
#  'Miracle_Warriors_Seal_of_the_Dark_Lord_(FM)_11_Terrarin',
#  'Space_Harrier_3_D_(FM)_08_Mysterious_Sky',
#  'Wonder_Boy_III_(FM)_06_Continue',
#  'Solomon_no_Kagi_(FM)_05_Pages_Room',
#  '04_Warp',
#  '06_Cemetery',
#  '14_Fortress',
#  'Golvellius_Valley_of_Doom_(FM)_08_Vertical_Scrolling_Cave',
#  'Kenseiden_(FM)_04_Chizuken_and_Kaga',
#  'Rampage_(FM)_04_Victory_Fanfare',
#  'Megumi_Rescue_(FM)_10_Game_Over',
#  '08_Boss_2',
#  'Penguin_Land_(FM)_02_Round_Start',
#  'Dynamite_Dux_(FM)_02_Boss',
#  '14_Bloody_Jewel_(Area_8)',
#  'Golvellius_Valley_of_Doom_(FM)_07_Randar',
#  'Summer_Games_(FM)_02_Opening',
#  '07_Go_Ahead_(Area_Clear)',
#  '08_Change_2',
#  'Space_Harrier_3_D_(FM)_17_Lovers',
#  '04_Course_Overview',
#  'Golvellius_Valley_of_Doom_(FM)_19_Fourth_Boss_Fosbus',
#  'Double_Dragon_(FM)_05_Mission_4',
#  'Alex_Kidd_The_Lost_Stars_(FM)_05_World_of_Make_Believe_The_Shrine_of_Jiggarat',
#  'California_Games_(FM)_06_Surfing',
#  '13_Ship',
#  '18_Ending',
#  'Phantasy_Star_(FM)_04_Shop',
#  'Captain_Silver_(FM)_08_Captain_Silver_s_Treasure_Island',
#  '02_User_Disk_Creation',
#  '17_Last_Scene',
#  'Miracle_Warriors_Seal_of_the_Dark_Lord_(FM)_09_Battle_Death',
#  '04_Title_Ending',
#  'Golvellius_Valley_of_Doom_(FM)_20_Fifth_Boss_Warlic',
#  'Summer_Games_(FM)_04_Pole_Vault',
#  'Rambo_III_(FM)_04_Scenes_2_5',
#  'Kenseiden_(FM)_10_Fail_in_Training',
#  '03_Hyper_Drive',
#  '01_Title',
#  'BMX_Trial_Alex_Kidd_02_South_Seas_Pyramid_River',
#  '10_Act_4',
#  '02_Technotris',
#  'Columns_(FM)_01_Filthy',
#  'Golvellius_Valley_of_Doom_(FM)_11_Enny',
#  '09_Area_3_(Electric_Woods_The_Fortress_City)',
#  '16_Ending_1',
#  '11_Act_5,_8',
#  'Miracle_Warriors_Seal_of_the_Dark_Lord_(FM)_12_Ending',
#  'Phantasy_Star_(FM)_07_Cave',
#  '09_Bio_Monster',
#  'Zillion_II_(FM)_02_Pure_Stone',
#  'Shanghai_(FM)_03_Music_Type_A',
#  'Ys_(FM)_06_Palace',
#  '09_Cavern',
#  'Captain_Silver_(FM)_11_Game_Over',
#  'Kenseiden_(FM)_07_Training_Entrance',
#  'Columns_(FM)_07_Concilation',
#  '07_Make_What_Haste_You_Can!',
#  '08_Boss_1',
#  'Phantasy_Star_(FM)_02_Intro',
#  'Miracle_Warriors_Seal_of_the_Dark_Lord_(FM)_05_Town',
#  '03_Cold_Amoeba',
#  '05_Victory',
#  '09_Neargead_Castle',
#  '02_Map',
#  'California_Games_(FM)_01_Louie_Louie',
#  'Kenseiden_(FM)_06_Yamato_and_Mito',
#  '21_Rooftop_(Thieves_Tower)',
#  '14_Extend_(Compile)',
#  'Phantasy_Star_(FM)_03_Town',
#  'Pro_Yakyuu_Family_Stadium_Pennant_Race_(MSX2,_MSX_Music)_01_Title_Screen',
#  'California_Games_(FM)_07_Skating',
#  'Phantasy_Star_(FM)_15_Tower',
#  '09_Level_5',
#  'Sky_Adventure_(Alpha_68K)_06_Boss',
#  '13_The_Final_Curtain',
#  'Galaxy_Force_(FM)_02_Beyond_the_Galaxy',
#  '03_Ready!',
#  '14_Visual_Great_Race_(Visual_Scene_3)',
#  'Ys_(FM)_02_Fountain_of_Love',
#  '05_Mission_1_Practice',
#  'Space_Harrier_3_D_(FM)_01_Main_BGM',
#  '13_Mission_5',
#  'Zillion_II_(FM)_04_Boss',
#  'Golvellius_Valley_of_Doom_(FM)_17_Third_Boss_Bachular',
#  'Summer_Games_(FM)_03_Event_Start',
#  'Fantasy_Zone_II_(FM)_09_Boss_Theme',
#  '09_Change_3',
#  'Zillion_II_(FM)_03_Inside_Base',
#  '01_Sample_1',
#  'Ys_(FM)_08_Palace_of_Destruction',
#  'Columns_(FM)_04_Lathesis',
#  'After_Burner_(FM)_02_Final_Take_Off',
#  '05_Town',
#  '09_Act_3',
#  'Golvellius_Valley_of_Doom_(FM)_15_Overworld_2',
#  'Fantasy_Zone_II_(FM)_08_Spardian',
#  'Shanghai_(FM)_02_Intro_Music_Type_C',
#  '03_Utility',
#  '06_Select_Your_Tactics!',
#  'Dynamite_Dux_(FM)_06_The_Achacha_Palace',
#  '14_Boss_5',
#  '05_Game_Set',
#  '10_Ending',
#  'Zillion_II_(FM)_01_Title_Screen',
#  '17_Ending_2',
#  'Ys_(FM)_18_Treasure_Box',
#  'Wonder_Boy_III_(FM)_05_Shop_(The_Dragon_s_Trap)',
#  'Power_Strike,_Aleste_(FM)_01_Aleste',
#  'Phantasy_Star_(FM)_21_Vehicle_(with_Airplane_SFX)',
#  '13_Shooting_Scene',
#  'Galaxy_Force_(FM)_07_Name_Entry',
#  '01_Sophistication_#1',
#  'Ys_(FM)_03_Tears_of_Sylph',
#  '17_Mission_7',
#  '03_Life_in_Space',
#  '17_Game_Over',
#  '04_Player_Stage_Select,_Parameter_Set',
#  'Zaxxon_3_D_(FM)_01_Title_Screen',
#  '01_Prologue',
#  'Kenseiden_(FM)_01_Title_Screen',
#  '03_Main_BGM',
#  'After_Burner_(FM)_01_Maximum_Power',
#  'Shanghai_(FM)_07_Unknown_1',
#  'Ys_(FM)_19_Game_Over',
#  '04_Main_BGM',
#  'Thunder_Blade_(FM)_05_Game_Over',
#  'Cyborg_Hunter_(FM)_02_Main_hallway',
#  'Ys_(FM)_20_Theme_of_Adol',
#  'Fantasy_Zone_II_(FM)_01_Title_Screen',
#  '13_Game_Over',
#  'BMX_Trial_Alex_Kidd_06_Jetpack',
#  '02_Team_Select',
#  '07_Metal_Creature_B',
#  'Galaxy_Force_(FM)_01_Scene_Select',
#  '02_Name_Entry',
#  'Captain_Silver_(FM)_01_Title_Screen',
#  '07_Mission_2',
#  'Power_Strike,_Aleste_(FM)_08_Don_t_Cry_Hi_yah',
#  'Alex_Kidd_The_Lost_Stars_(FM)_04_Machine_World_Giant_s_Body',
#  '01_Hyper_Defending_Force_(Title)',
#  '06_Stage_4',
#  '12_Red_Zone_(Area_6)',
#  '03_Stage_1',
#  'Rambo_III_(FM)_02_Scenes_1_4',
#  'Shanghai_(FM)_08_Unknown_2',
#  '17_Ending_1',
#  '02_Opening_1',
#  '02_Game_Select',
#  'Summer_Games_(FM)_07_Gymnastics',
#  '05_Time',
#  'Wonder_Boy_in_Monster_Land_(FM)_08_So_Long',
#  'Phantasy_Star_(FM)_19_Game_Over',
#  '16_Unused_2',
#  '03_Opening_Theme',
#  '20_Boss_8',
#  'Miracle_Warriors_Seal_of_the_Dark_Lord_(FM)_06_Cavern',
#  'Wonder_Boy_III_(FM)_02_Vs._Dragon',
#  '11_Stage_5',
#  '24_Ending',
#  '03_Opening_2',
#  '03_Game_Start',
#  '04_Game_de_check!_Koutsuu_Anzen_(FM)_Speed_Sense',
#  'Global_Defense_(FM)_05_We_are_Desirous_of_Peace_(Ending)',
#  'Zillion_II_(FM)_05_Push!',
#  'BMX_Trial_Alex_Kidd_04_Course_Clear',
#  'Wonder_Boy_III_(FM)_04_Monster_Town',
#  'Galactic_Protector_(FM)_01_Title_Screen',
#  '03_Game_de_check!_Koutsuu_Anzen_(FM)_Driving_Eye',
#  'Thunder_Blade_(FM)_01_Title_Screen',
#  '01_Title_~_Home_Run',
#  'Galactic_Protector_(FM)_02_Earth_Round',
#  'Rampage_(FM)_06_Unknown',
#  'Galactic_Protector_(FM)_08_Game_Over',
#  'Rastan_(FM)_08_Game_Over',
#  '01_Opening_Theme_1',
#  'Miracle_Warriors_Seal_of_the_Dark_Lord_(FM)_03_Overhead',
#  'Penguin_Land_(FM)_06_Unknown_Music',
#  '15_Dogodaga_Dogodege_(Final_Boss)',
#  'Captain_Silver_(FM)_07_Boat_Cave',
#  '05_Game_de_check!_Koutsuu_Anzen_(FM)_Driving_Technique',
#  '03_Title_Screen',
#  '10_Forest',
#  'California_Games_(FM)_02_Menu',
#  '14_Pirate_Island',
#  '02_Opening_Theme_2',
#  'Space_Harrier_3_D_(FM)_15_Wiwi_Jumbo',
#  'Ys_(FM)_14_Final_Battle',
#  '14_Staff_Roll_(Short)',
#  '08_Solgrado',
#  '13_Staff_Roll',
#  '06_Staff_Roll',
#  'Wonder_Boy_III_(FM)_08_Side_Crawler_s_Dance',
#  'Captain_Silver_(FM)_02_Scene_Start',
#  'Space_Harrier_3_D_(FM)_04_Stanley',
#  '09_Ruins',
#  '01_Is_it_Domingo_Today',
#  '11_Boss',
#  '03_Sample_3',
#  'Rastan_(FM)_05_The_Devil_Boss_Carnival',
#  'Golvellius_Valley_of_Doom_(FM)_30_Unknown',
#  '09_Clear',
#  '04_Metal_Creature_A',
#  'Fantasy_Zone_II_(FM)_14_Game_Over',
#  'Global_Defense_(FM)_02_Start',
#  '11_Game_de_check!_Koutsuu_Anzen_(FM)_Pyonko_Chan_Try_Harder_Next_Time',
#  '26_Cavern_(Labyrinth)',
#  'Alex_Kidd_The_Lost_Stars_(FM)_03_Toy_World_Monster_World',
#  'Zaxxon_3_D_(FM)_03_Enemy_s_Base',
#  '06_Over',
#  'Double_Dragon_(FM)_08_Mission_Complete',
#  'Summer_Games_(FM)_06_100m_Dash_End',
#  '07_Love_in_Space',
#  'Dynamite_Dux_(FM)_03_Pseudo_Japan',
#  '28_Eye_Catch',
#  '08_Stage_2',
#  '13_Stage_8',
#  '05_Colonel_Claud_(Miniboss)',
#  'Fantasy_Zone_II_(FM)_07_Fuwareak',
#  'Cyborg_Hunter_(FM)_01_Title_Screen',
#  'Space_Harrier_3_D_(FM)_19_Battle_Field',
#  '09_Game_de_check!_Koutsuu_Anzen_(FM)_Pyonkichi_s_Adventure',
#  '12_Game_Set_(Lose)',
#  'Columns_(FM)_02_Quagmire',
#  '05_Sample_5',
#  'Power_Strike,_Aleste_(FM)_07_Rapid_Turning',
#  'Out_Run_(FM)_02_Passing_Breeze',
#  'Phantasy_Star_(FM)_09_Vehicle',
#  '05_Area_Clear',
#  'Rambo_III_(FM)_05_Scenes_3_6',
#  '02_Select_Weapon',
#  '06_Chance_BGM',
#  'Golvellius_Valley_of_Doom_(FM)_02_Intro',
#  '16_Game_Over',
#  '04_Stage_2',
#  'Maze_Hunter_3_D_(FM)_03_Rugged_Area',
#  '08_Travelers_Inn_(Disappearance_of_the_King_s_Scepter)',
#  'Columns_(FM)_06_Boy_Wonder',
#  '06_Boss_1',
#  '15_Spanish_Communist_Party',
#  'Fantasy_Zone_II_(FM)_12_Last_Boss',
#  '17_Boss_3',
#  '15_Dragon',
#  '12_Continue',
#  '15_Mission_6',
#  'Golvellius_Valley_of_Doom_(FM)_01_Title',
#  'Penguin_Land_(FM)_01_Title_Screen',
#  'Zaxxon_3_D_(FM)_04_Boss',
#  'Ys_(FM)_16_The_Morning_Grow',
#  'Phantasy_Star_(FM)_18_Ending',
#  '02_Area_1_(Graveyard_The_Deep_Sea)',
#  'California_Games_(FM)_11_Shark',
#  'Space_Harrier_3_D_(FM)_02_Title',
#  'Penguin_Land_(FM)_04_Main_Theme',
#  'Zaxxon_3_D_(FM)_06_Mission_Complete',
#  '15_Unused_1',
#  '02_Mode_Select',
#  'Power_Strike,_Aleste_(FM)_13_Easygoing',
#  'Galactic_Protector_(FM)_04_Saturn_Round',
#  '17_Triumph_(Ending)',
#  'Golvellius_Valley_of_Doom_(FM)_04_First_Cave',
#  '10_Light_Step',
#  'Alex_Kidd_The_Lost_Stars_(FM)_09_Time_Up_The_End',
#  'Miracle_Warriors_Seal_of_the_Dark_Lord_(FM)_08_Battle_Victory',
#  'Summer_Games_(FM)_05_100m_Dash',
#  'Megumi_Rescue_(FM)_06_Bonus_Stage',
#  'Wonder_Boy_in_Monster_Land_(FM)_07_Labyrinth_of_No_End',
#  'Golvellius_Valley_of_Doom_(FM)_23_Sixth_Boss_Crawky',
#  'Out_Run_3D_(FM)_03_Color_Ocean',
#  '06_Boss',
#  '11_Game_Set_(Draw)',
#  'Power_Strike,_Aleste_(FM)_05_The_Devastation',
#  'Maze_Hunter_3_D_(FM)_08_Game_Over',
#  '06_Hot_Road',
#  '20_Epilogue',
#  '05_Street_Fighter_(Sub_Boss)',
#  'Cyborg_Hunter_(FM)_08_Game_Over',
#  'Kenseiden_(FM)_11_Black_Magic_Castle',
#  '16_Again_(Game_Over)',
#  'Alex_Kidd_The_Lost_Stars_(FM)_08_Ending',
#  'Captain_Silver_(FM)_05_Boss',
#  'Kenseiden_(FM)_13_Yonensai,_The_Master',
#  'Wonder_Boy_III_(FM)_03_And_Now...',
#  'Penguin_Land_(FM)_05_Round_Clear',
#  '15_Game_Over',
#  'Wonder_Boy_in_Monster_Land_(FM)_06_Flute',
#  'Ys_(FM)_09_Beat_of_the_Terror',
#  '60_Scenario_Clear',
#  '06_Rapid_Turning_(Area_Boss)',
#  'Wonder_Boy_in_Monster_Land_(FM)_05_Cave_Castle',
#  '12_Aerial_Castle_Appearance',
#  'Dynamite_Dux_(FM)_08_Ending',
#  '08_Village_Town',
#  'Summer_Games_(FM)_08_Platform_Diving',
#  'Rastan_(FM)_02_Aggressive_World',
#  'Phantasy_Star_(FM)_06_Battle',
#  'Rambo_III_(FM)_06_Scene_7',
#  'Phantasy_Star_(FM)_08_Church',
#  '11_Mission_4',
#  '02_Sample_2',
#  '02_Moon_Light_Sonata',
#  '04_Driver_Info',
#  'After_Burner_(FM)_04_Super_Stripe',
#  'Captain_Silver_(FM)_04_Eerie_Piper',
#  'Rastan_(FM)_03_Bad_Bible',
#  '07_Get_the_Luck',
#  '04_The_March_of_Heroes',
#  'Megumi_Rescue_(FM)_07_Rounds_11_20',
#  'Thunder_Blade_(FM)_02_Burning_Point',
#  '12_Boss_4',
#  '02_Opening_#2',
#  'Golvellius_Valley_of_Doom_(FM)_27_Ending',
#  '08_Flying_on_a_String',
#  'Ys_(FM)_10_Temple_del_Sol',
#  'Maze_Hunter_3_D_(FM)_06_Blaze_Area',
#  '04_Sample_4',
#  'Phantasy_Star_(FM)_17_Dark_Falz',
#  '12_Stage_Clear',
#  'Maze_Hunter_3_D_(FM)_02_Metal_Area',
#  '11_Stage_6',
#  '13_Drunkard',
#  'Golvellius_Valley_of_Doom_(FM)_14_Second_Boss_Rolick',
#  '08_Battle',
#  'Kenseiden_(FM)_08_Training_Round',
#  'Golvellius_Valley_of_Doom_(FM)_24_Seventh_Boss_Haidee',
#  'Zaxxon_3_D_(FM)_07_Game_Over',
#  'Phantasy_Star_(FM)_11_Motavia',
#  '18_Boss_7',
#  'Wonder_Boy_in_Monster_Land_(FM)_04_Shop',
#  '07_Change_1',
#  '06_Game_de_check!_Koutsuu_Anzen_(FM)_Risk_Control',
#  'Kenseiden_(FM)_05_Iyo_and_Suraga',
#  'Power_Strike,_Aleste_(FM)_06_The_Solitude',
#  '05_Scramble_Story_Demo',
#  'Double_Dragon_(FM)_09_Ending',
#  'Maze_Hunter_3_D_(FM)_05_Ice_Area',
#  'Alex_Kidd_The_Lost_Stars_(FM)_01_Title_Screen',
#  'Rambo_III_(FM)_08_Ending',
#  '05_Old_Master_s_House',
#  '10_Demo_1',
#  'Solomon_no_Kagi_(FM)_06_Princess_Room',
#  'Dynamite_Dux_(FM)_04_Almost_Chicago',
#  'Summer_Games_(FM)_10_100m_Freestyle_End',
#  '14_Aerial_Castle_Kwol',
#  'Cyborg_Hunter_(FM)_03_Level_A_D',
#  '15_Last_Boss',
#  'Wonder_Boy_III_(FM)_14_The_Dragon_s_Trap',
#  '05_Out_of_Rap',
#  'Miracle_Warriors_Seal_of_the_Dark_Lord_(FM)_02_Name_Entry',
#  '08_Visual_Alien_(Visual_Scene_1)',
#  '11_Ending',
#  'Solomon_no_Kagi_(FM)_04_Hurry_Up',
#  'Golvellius_Valley_of_Doom_(FM)_28_Input_Password',
#  'Summer_Games_(FM)_09_100m_Freestyle',
#  '03_Traditional_Bar',
#  'Global_Defense_(FM)_03_System_Down_(In_Game)',
#  'Ys_(FM)_05_First_Step_Towards_Wars',
#  '02_Title',
#  'Fantasy_Zone_II_(FM)_13_Ending_Theme',
#  '10_Game_de_check!_Koutsuu_Anzen_(FM)_Pyonko_Chan_Well_Done',
#  'Cyborg_Hunter_(FM)_04_Level_B_E',
#  '12_Stage_7',
#  'Cyborg_Hunter_(FM)_05_Level_C_F',
#  'California_Games_(FM)_09_Flying_Disk',
#  '07_Stage_5',
#  'Power_Strike,_Aleste_(FM)_03_Tension_of_Dark_Side',
#  'Rampage_(FM)_01_Title_Screen',
#  'Golvellius_Valley_of_Doom_(FM)_25_Final_Cave',
#  'Disc_Station_01_Title_Screen_(FM)',
#  'Golvellius_Valley_of_Doom_(FM)_05_Old_Woman',
#  'Golvellius_Valley_of_Doom_(FM)_29_Game_Over',
#  '12_Event_Clear',
#  'California_Games_(FM)_04_Half_Pipe',
#  'Dynamite_Dux_(FM)_05_Little_Texas',
#  '02_Recon_Story_Demo',
#  'Shanghai_(FM)_01_Title_Screen',
#  '02_Play_Ball',
#  'Space_Harrier_3_D_(FM)_05_Vakda',
#  'Shanghai_(FM)_04_Music_Type_B',
#  '02_Constructor',
#  'Rampage_(FM)_07_Title_Screen_(Fast)',
#  'Megumi_Rescue_(FM)_11_Unused_Jingle',
#  'Summer_Games_(FM)_01_Title_Screen',
#  '01_Compile',
#  'Golvellius_Valley_of_Doom_(FM)_18_Dina',
#  '06_Dass_XXX',
#  'Space_Harrier_3_D_(FM)_12_Ida',
#  'California_Games_(FM)_03_Event_Intro',
#  'Wonder_Boy_III_(FM)_13_Endless_War',
#  'Captain_Silver_(FM)_10_Ending',
#  '12_Area_5_(Van_Allen_The_Alien_Attack)',
#  'Kenseiden_(FM)_02_Higo,_Nagato,_Settsu,_Owari_and_Echyu',
#  '11_Voice_of_God',
#  'F1_Douchuuki_(MSX2,_OPLL)_01_Title_Screen',
#  'Cyborg_Hunter_(FM)_06_Boss_Room',
#  'Miracle_Warriors_Seal_of_the_Dark_Lord_(FM)_10_New_Companion',
#  '09_Tension_of_Dark_Side_(Area_3)',
#  '10_Boss_3',
#  'BMX_Trial_Alex_Kidd_03_Radaxian',
#  '01_Last_Attack',
#  '10_GAMP_Mission',
#  '08_Rocks',
#  'Wonder_Boy_III_(FM)_10_Mouse_Man_Falling',
#  'Rampage_(FM)_02_Character_Selection',
#  '04_Act_1,_6',
#  'Golvellius_Valley_of_Doom_(FM)_03_Overworld_1',
#  '14_Conspirators',
#  '10_Dungeon',
#  '02_Game_de_check!_Koutsuu_Anzen_(FM)_Practice,_Starting',
#  '19_Mission_8',
#  'Solomon_no_Kagi_(FM)_03_Hidden_Room',
#  'Power_Strike,_Aleste_(FM)_12_Triumph',
#  '01_Opening_#1',
#  'Rambo_III_(FM)_07_Mil_Hind_Helicopter',
#  'Altered_Beast_(FM)_05_Ending',
#  'Megumi_Rescue_(FM)_09_Ending',
#  '10_Castle',
#  '01_Game_de_check!_Koutsuu_Anzen_(FM)_Instructions',
#  '11_Visual_Theme_of_Stacy_(Visual_Scene_2)',
#  'Ys_(FM)_13_The_Last_Moment_of_the_Dark',
#  'California_Games_(FM)_05_Foot_Bag',
#  'Sky_Adventure_(Alpha_68K)_16_Game_Over',
#  'Megumi_Rescue_(FM)_05_Bonus_Start',
#  'Solomon_no_Kagi_(FM)_10_Game_Over',
#  'Maze_Hunter_3_D_(FM)_01_Title_Screen',
#  '02_Prologue_DIA51',
#  '04_Chance_BGM',
#  'Ys_(FM)_04_The_Syonin',
#  'Megumi_Rescue_(FM)_03_Round_Clear',
#  'After_Burner_(FM)_06_City_202',
#  '12_Stage_6',
#  'Wonder_Boy_in_Monster_Land_(FM)_03_Town',
#  'Global_Defense_(FM)_06_SDI_Blue_Moon_(Game_Over)',
#  'Galactic_Protector_(FM)_03_Round_Clear',
#  'Rambo_III_(FM)_03_Scene_Clear',
#  '25_Water_Pipe',
#  'Space_Harrier_3_D_(FM)_10_Game_Over',
#  'Dynamite_Dux_(FM)_01_Downtown_Achacha_City',
#  'Ys_(FM)_07_Holders_of_Power',
#  'Ys_(FM)_11_Tower_of_the_Shadow_of_Death',
#  'Rastan_(FM)_04_Re_In_Carnation',
#  'Space_Harrier_3_D_(FM)_18_Lake_Side_Memory',
#  'Phantasy_Star_(FM)_13_Village',
#  'Altered_Beast_(FM)_03_Unused_Story',
#  '23_Event',
#  'Fantasy_Zone_II_(FM)_05_Bow_Bow',
#  'Power_Strike,_Aleste_(FM)_15_Extra_Life',
#  'Wonder_Boy_in_Monster_Land_(FM)_01_Main_Theme',
#  '46_Shock',
#  '18_Ending_2',
#  '10_Area_4_(Clouds_The_Air_Castle)',
#  'Ys_(FM)_12_Devil_s_Wind',
#  'Phantasy_Star_(FM)_12_Final_Dungeon',
#  '05_Setting',
#  'Rastan_(FM)_07_The_Man_of_Saga',
#  '23_Giant_Thexder',
#  'Galaxy_Force_(FM)_04_Defeat',
#  'Summer_Games_(FM)_11_Unused',
#  'Golvellius_Valley_of_Doom_(FM)_10_Victory',
#  '12_Credits',
#  '16_Visual_Wedding_(Hidden_Ending)',
#  '08_Ice',
#  '19_Staff_Roll',
#  'California_Games_(FM)_10_Success',
#  'Super_Basketball_(FM)_01_Background_Music',
#  'BMX_Trial_Alex_Kidd_01_Blackwood_Forest_Cactus_Desert',
#  '01_Pikupiku_Team',
#  'Disc_Station_02_Menu_(FM)',
#  'Rastan_(FM)_01_Opening',
#  'Galaxy_Force_(FM)_05_Take_Back',
#  'Fantasy_Zone_II_(FM)_10_Boss_Defeated',
#  'Space_Harrier_3_D_(FM)_03_Ending',
#  '15_Ending_#2',
#  'Double_Dragon_(FM)_07_Last_Boss',
#  '18_Ending_3',
#  '11_Your_Rank',
#  '12_Game_Over_(Namco_Logo,_The_Tower_of_Druaga)',
#  '42_GET_Item']
